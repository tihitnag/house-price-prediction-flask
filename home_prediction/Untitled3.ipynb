# %%
import pandas as pd
import numpy as np
import seaborn as sns

df1=pd.read_csv("C:/Users/Ivar/Downloads/kc_house_data.csv")
df1.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df1.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df1.describe()
df1.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=[10,6])
sns.distplot(x=df1['price'])
# Out:
# C:\Users\Ivar\AppData\Local\Temp\ipykernel_13256\2604332559.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df1['price'])
# <Axes: ylabel='Density'>

# %%
sns.boxplot(x=df1['price'])
# Out:
# <Axes: xlabel='price'>

# %%
fig=plt.figure(figsize=[16,6])
fig.add_subplot(2,2,1)
sns.scatterplot(x=df1['sqft_above'], y=df1['price'])
fig.add_subplot(2,2,2)
sns.scatterplot(x=df1['sqft_living'], y=df1['price'])

fig.add_subplot(2,2,3)
sns.scatterplot(x=df1['sqft_lot'], y=df1['price'])
# Out:
# <Axes: xlabel='sqft_lot', ylabel='price'>

# %%
fig=plt.figure(figsize=(15,7))

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

# Plotting countplots on respective subplots
sns.countplot(x=df1['view'], ax=ax1)
sns.countplot(x=df1['bedrooms'], ax=ax2)
sns.countplot(x=df1['floors'], ax=ax3)
sns.countplot(x=df1['grade'], ax=ax4)
plt.tight_layout()

# %%
df1.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
import pandas as pd
df1['date'] = pd.to_datetime(df1['date'])

df1['year'] = df1['date'].dt.year
df1['month'] = df1['date'].apply(lambda date:date.month)

# %%
fig=plt.figure(figsize=(15,7))
fig.add_subplot(2, 2, 1)
df1.groupby('month').mean()['price'].plot()
fig.add_subplot(2, 2, 2)
df1.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
df1 = df1.drop('date',axis=1)
df1= df1.drop('id',axis=1)
df1 = df1.drop('zipcode',axis=1)

# %%
df1.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
x=df1.drop('price',axis=1)
y=df1['price'].values
x.head(3)
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10
# 1  47.7210 -122.319           1690        7639  2014     12
# 2  47.7379 -122.233           2720        8062  2015      2

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=101)

# %% [raw]
# from sklearn.preprocessing import StandardScaler
#
# x_scaler = StandardScaler()
# x_train = x_scaler.fit_transform(x_train.astype(np.float))
# x_test = x_scaler.transform(x_test.astype(np.float))

# %%
#model 1
from sklearn.linear_model import LinearRegression
model = LinearRegression()  
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#evaluate the model (intercept and slope)
print('intercept',model.intercept_)
print('cof',model.coef_)
y_pred=model.predict(x_test)
# Out:
# intercept -109615422.72291398
# cof [-3.27530795e+04  3.74883530e+04  1.08616502e+02  1.40780661e-01
#   4.69683335e+03  5.60897886e+05  4.80246718e+04  3.44531763e+04
#   9.86366316e+04  6.90782343e+01  3.95382680e+01 -2.42463146e+03
#   2.19161851e+01  5.63744605e+05 -1.19852641e+05  2.95835386e+01
#  -3.88231427e-01  3.58357693e+04  1.17091453e+03]

# %%
error=y_pred-y_test
error
sns.distplot(error)
# Out:
# C:\Users\Ivar\AppData\Local\Temp\ipykernel_13256\3568251114.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(error)
# <Axes: ylabel='Density'>

# %%
predition_compasrsion=pd.DataFrame({'actual':y_test,'predict':y_pred})
predition_compasrsion.head(10)
# Out:
#      actual        predict
# 0  349950.0  525752.161234
# 1  450000.0  669348.918486
# 2  635000.0  552270.444702
# 3  355500.0  349772.401937
# 4  246950.0   64178.194244
# 5  406550.0  491199.051586
# 6  350000.0  312921.528468
# 7  226500.0  272613.811314
# 8  265000.0  279984.348274
# 9  656000.0  529774.758589

# %%
# evaluate the performance of the algorithm (MAE - MSE - RMSE)
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))  
print('MSE:', metrics.mean_squared_error(y_test, y_pred))  
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('VarScore:',metrics.explained_variance_score(y_test,y_pred))
# Out:
# MAE: 122004.70014927616
# MSE: 39900085685.59399
# RMSE: 199750.0580365222
# VarScore: 0.7075585075954398

# %%
#try diffrent odel like deras in deep learning 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation
from tensorflow.optimizer import Adam
#add 4 layer network
model_2=sequtial()
model_2.add(Dense(19,activation='relu'))

# %%
import json
my_columns={
    "data_columns":[col.lower( )for col in x.columns]
}
with open('my_coloumns.json','w')as f:
    
    f.write(json.dumps(my_columns))

# %%
import pickle 
with open("my_house_Data.pickle","wb") as f:
    pickle.dump(model,f)
